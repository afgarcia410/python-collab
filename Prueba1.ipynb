# %% [markdown]
# <a href="https://colab.research.google.com/github/afgarcia410/python-collab/blob/main/Prueba1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python

# %%
#Versión de Python
# !python --version
# Out:
# Python 3.8.10

# %%
# !pip install pillow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#cuaderno de jupyter
lenguaje = 'Python 3.9'

# %%
print(lenguaje)

# %%
def ejemplo():
  return 3;

# %%
ejemplo()

# %%
from PIL import Image
im = Image.open('foto.jpg')
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1338x752 at 0x7F187B0BAE20>
